# %%
# !pip3 install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Downloading mysql_connector_python-9.7.0-cp311-cp311-manylinux_2_28_x86_64.whl (21.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 5.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.7.0

# %%
import mysql.connector
from mysql.connector import Error

def test_connection():
    try:
        # Replace with your actual database credentials
        connection = mysql.connector.connect(
            host='mysql_univ_db',       # e.g., '127.0.0.1' or server IP
            port='3306',
            database='transaction_db',     # optional for just testing connection
            user='root',   # default is often 'root'
            password='airflow'
        )

        if connection.is_connected():
            db_info = connection.get_server_info()
            print(f"Successfully connected to MySQL Server version {db_info}")
            
            # Use a cursor to run a simple test query
            cursor = connection.cursor()
            cursor.execute("SELECT DATABASE();")
            record = cursor.fetchone()
            print(f"You're connected to database: {record}")

    except Error as e:
        print(f"Error while connecting to MySQL: {e}")
    finally:
        if 'connection' in locals() and connection.is_connected():
            cursor.close()
            connection.close()
            print("MySQL connection is closed")

if __name__ == "__main__":
    test_connection()
# Out:
# Successfully connected to MySQL Server version 8.0.45
# You're connected to database: ('transaction_db',)
# MySQL connection is closed
# /tmp/ipykernel_131/2114538034.py:16: DeprecationWarning: Call to deprecated function get_server_info. Reason:
#     The property counterpart 'server_info' should be used instead.
#
#   db_info = connection.get_server_info()
