# %%
# !pip3 install clickhouse_connect
# Out:
# Collecting clickhouse_connect
#   Downloading clickhouse_connect-1.0.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from clickhouse_connect) (2023.7.22)
# Requirement already satisfied: urllib3>=1.26 in /opt/conda/lib/python3.11/site-packages (from clickhouse_connect) (2.0.7)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.11/site-packages (from clickhouse_connect) (0.21.0)
# Requirement already satisfied: lz4 in /opt/conda/lib/python3.11/site-packages (from clickhouse_connect) (4.3.2)
# Downloading clickhouse_connect-1.0.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: clickhouse_connect
# Successfully installed clickhouse_connect-1.0.1

# %%
import clickhouse_connect

import logging

client = clickhouse_connect.get_client(host='clickhouse_server', port=8123, username='airflow', 
                                       password='airflow', database='transaction_db')

# %%
with open('create_table.sql', 'r') as f:
    create_sql = f.read()

# %%
client.command(create_sql)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 client.command(create_sql)
#
# File /opt/conda/lib/python3.11/site-packages/clickhouse_connect/driver/httpclient.py:468, in HttpClient.command(self, cmd, parameters, data, settings, use_database, external_data, transport_settings)
#     466 headers = dict_copy(headers, transport_settings)
#     467 method = "POST" if payload or fields else "GET"
# --> 468 response = self._raw_request(payload, params, headers, method, fields=fields, server_wait=False)
#     469 if response.data:
#     470     try:
#
# File /opt/conda/lib/python3.11/site-packages/clickhouse_connect/driver/httpclient.py:599, in HttpClient._raw_request(self, data, params, headers, method, retries, stream, server_wait, fields, error_handler, retry_body)
#     597     error_handler(response)
#     598 else:
# --> 599     self._error_handler(response)
#
# File /opt/conda/lib/python3.11/site-packages/clickhouse_connect/driver/httpclient.py:511, in HttpClient._error_handler(self, response, retried)
#     508 finally:
#     509     response.close()
# --> 511 raise OperationalError(err_str) if retried else DatabaseError(err_str) from None
#
# DatabaseError: Received ClickHouse exception, code: 62, server response: Code: 62. DB::Exception: Syntax error (Multi-statements are not allowed): failed at position 19 (end of query) (line 1, col 19): ;
#
# DROP TABLE IF EXISTS transaction_db.transaction_raw;
#
# CREATE TABLE transaction_db.transaction_raw (
#     `year` UInt16 ,
#     `month` UInt8 ,
#     `id` UInt64 ,
#     `ho... . (SYNTAX_ERROR) (for url http://clickhouse_server:8123)
